# %% [markdown]
# fraccion = \ frac (a)(b)

# %%
x=

# %% [markdown]
# $\frac{5}{2}$

# %% [markdown]
# $\sqrt[8]{z}$

# %%
#variables 
a=3

# %%
input("introduce tu edad ")
# Out:
# introduce tu edad 44
# '44'

# %%
edad=input("introduce tu edad")
edad=int(edad)
print(' el doble de tu edad es:', 2* edad )
# Out:
# introduce tu edad12
#  el doble de tu edad es: 24

# %%
lado  = input ('ingrese el valor del lado de un cuadrado ')
lado=int(lado)
area=lado**2
print(' el area del cuadrado es',lado, 'esta dado por '
# Out:
# ingrese el valor del lado de un cuadrado 45

# %%
 #definicion de funciones 
 def f(x):
    y=3*x**2+5
    return(y)

# %%
nombre=input("ingrese su nombre")
def saludar (nombre)
   return(print("hola",nombre,"bienvenido al curso "))
saludar(nombre)

# %%
def   cuadrasuma (x,y):
  z=(x+y)**2
  return(z)

# %%
cuadrasuma(2,3)
# Out:
# 25

# %%
25**0.5
# Out:
# 5.0

# %%
def solcuadratica(a,b,c):
  sol1=(-b+(b**2 - 4*a*c)**0.5)/(2*a)
  sol2=(-b-(b**2 -4*a*c)**0.5)/(2*a)
  return(print(sol1,sol2))

# %%
solcuadratica(1,-3,2)
# Out:
# 2.0 1.0

# %%
a=2
b=9
c=10
