# %% [markdown]
# ejercicio
# haga un codigo que de como resultado el vertie de una funcion cuadratica f(x)=ax2+bx+c

# %%
#funcion que da el vertie de una función 
a=2
b=3  # estos son los coeficientes de la función cuadratica 
c=4
X=-b/(2*a)
Y=(-b**2 + 4*a*c)/(4*a)
print("El vertice tiene cordenada en X=",X,"\nEl vertice tiene cordenada en Y=",Y)
# Out:
# El vertice tiene cordenada en X= -0.75
# El vertice tiene cordenada en Y= 2.875

# %%
#funcion que calcula el vertice de una funcion cuadratica 
def calcularvertice (a,b,c):
  X=-b/(2*a)
  Y=(-b**2 + 4*a*c)/(4*a)
  print("El vertice tiene cordenada en X=",X,"\nEl vertice tiene cordenada en Y=",Y)

# %%
calcularvertice (2,3,4)
# Out:
# El vertice tiene cordenada en X= -0.75
# El vertice tiene cordenada en Y= 2.875

# %% [markdown]
# # condicionales

# %%
2==6
# Out:
# False

# %%
3+9==6*2
# Out:
# True

# %%
x = input("ingrese un numero natural")
x= int(x)
if x > 3 :
  print("el numero",x,"es mayor que 3")
# Out:
# ingrese un numero natural4
# el numero 4 es mayor que 3

# %%
x = input("ingrese un numero natural")
x= int(x)
if x > 53 :
  print("el numero",x,"es mayor que 53")
else:
    print("el numero",x,"es menor igual que 53")
# Out:
# ingrese un numero natural45
# el numero 45 es menor igual que 53

# %%
#escriba un codigo que determine si un numero dado es par o impar 
x = input("ingrese un numero natural")
x= int(x)
if x%2==0:
  print("El numero es par")
else:
    print("el numero es impar")
# Out:
# ingrese un numero natural15
# el numero es impar

# %%
def calcularvertice(a,b,c):
  if a == 0:
    print("La función no es cuadrtica")
  else:
    if a > 0:
      print("La gráfica de la función es una parabola que abre hacia arriba")
    if a < 0:
      print("La gráfica de la función es una parabola que abre hacia abajo")
    x = -b/(2*a)
    Y = (-b**2 + 4*a*c) / (4*a)
    print("El vertice tiene coordenada en x =",x_0,"\nEl vertice tiene coordenada en y =", y_0)
