# %%
2+3 #suma de numeros
# Out:
# 5

# %%
2*3
# Out:
# 6

# %%
50/10
# Out:
# 5.0

# %%
5-2*6
# Out:
# -7

# %%
3**4
# Out:
# 81

# %%
(0.3)+(0.4)
# Out:
# 0.7

# %%
10%4
# Out:
# 2

# %% [markdown]
# resuido%
# cociente //

# %%
25//7
# Out:
# 3

# %%
#imprimir en pantalla 
print("hola")
# Out:
# hola

# %%
print("cudrado de 3 es",3**2)
# Out:
# cudrado de 3 es 9
